# %% [markdown]
# Neuronal net with cylinical split data

# %%
# ============================================================
# 0) Imports
# ============================================================
# %pip -q install tensorflow scikit-learn joblib

import os
import numpy as np
import pandas as pd

from sklearn.preprocessing import StandardScaler
import joblib

import tensorflow as tf
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization, InputLayer
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.optimizers import Adam
# Out:
# [notice] A new release of pip is available: 25.1.1 -> 25.3
# [notice] To update, run: python -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
# ============================================================
# 1) Load your pre-split data
# ============================================================
TRAIN_PATH = "/workspaces/bakery_prediction/0_DataPreparation/Split_data/03_cylindical/train_data.csv"
VAL_PATH   = "/workspaces/bakery_prediction/0_DataPreparation/Split_data/03_cylindical/val_data.csv"
TEST_PATH  = "/workspaces/bakery_prediction/0_DataPreparation/Split_data/03_cylindical/test_data.csv"

train_df = pd.read_csv(TRAIN_PATH)
val_df   = pd.read_csv(VAL_PATH)
test_df  = pd.read_csv(TEST_PATH)

# if you have a date column, parse it (optional for the NN, useful for checks)
if "Datum" in train_df.columns:
    train_df["Datum"] = pd.to_datetime(train_df["Datum"])
    val_df["Datum"]   = pd.to_datetime(val_df["Datum"])
    test_df["Datum"]  = pd.to_datetime(test_df["Datum"])

print(train_df.shape, val_df.shape, test_df.shape)
train_df.head()
# Out:
# (7493, 23) (1841, 23) (1830, 23)
#         id      Datum  Warengruppe      Umsatz  KielerWoche  Bewoelkung  \
# 0  1307011 2013-07-01            1  148.828353            0           6
# 1  1307012 2013-07-01            2  535.856285            0           6
# 2  1307013 2013-07-01            3  201.198426            0           6
# 3  1307014 2013-07-01            4   65.890169            0           6
# 4  1307015 2013-07-01            5  317.475875            0           6
#
#    Temperatur  Windgeschwindigkeit  Woche  Monat  ...  Ferien  sunny  cloudy  \
# 0     17.8375                   15     27      7  ...       0      0       1
# 1     17.8375                   15     27      7  ...       0      0       1
# 2     17.8375                   15     27      7  ...       0      0       1
# 3     17.8375                   15     27      7  ...       0      0       1
# 4     17.8375                   15     27      7  ...       0      0       1
#
#    rainy  thunderstorm  is_weekend  sin_Monat  cos_Monat  sin_Wochentag  \
# 0      0             0           0       -0.5  -0.866025       0.781831
# 1      0             0           0       -0.5  -0.866025       0.781831
# 2      0             0           0       -0.5  -0.866025       0.781831
# 3      0             0           0       -0.5  -0.866025       0.781831
# 4      0             0           0       -0.5  -0.866025       0.781831
#
#    cos_Wochentag
# 0        0.62349
# 1        0.62349
# 2        0.62349
# 3        0.62349
# 4        0.62349
#
# [5 rows x 23 columns]

# %%
# ============================================================
# 2) Define target + feature columns
#    (adjust drop list to your columns)
# ============================================================
TARGET_COL = "Umsatz"

drop_cols = []
for c in ["id", "Datum"]:
    if c in train_df.columns:
        drop_cols.append(c)

# IMPORTANT: avoid leakage for forecasting:
# if Umsatz_roll is computed using future values, drop it.
# If it's computed only from past values at that date, it can stay.
if "Umsatz_roll" in train_df.columns:
    drop_cols.append("Umsatz_roll")

feature_cols = [c for c in train_df.columns if c not in drop_cols + [TARGET_COL]]

X_train = train_df[feature_cols].copy()
y_train = train_df[TARGET_COL].copy()

X_val   = val_df[feature_cols].copy()
y_val   = val_df[TARGET_COL].copy()

X_test  = test_df[feature_cols].copy()
y_test  = test_df[TARGET_COL].copy()

print("n_features:", len(feature_cols))
# Out:
# n_features: 20

# %%
# ============================================================
# 3) Scale features (fit ONLY on train)
# ============================================================
scaler = StandardScaler()
X_train_s = scaler.fit_transform(X_train)
X_val_s   = scaler.transform(X_val)
X_test_s  = scaler.transform(X_test)

os.makedirs("3_Model/class file/pickle_data", exist_ok=True)
joblib.dump(scaler, "3_Model/class file/pickle_data/scaler.joblib")
pd.to_pickle(feature_cols, "3_Model/class file/pickle_data/feature_cols.pkl")

# %%
# ============================================================
# 4) Build + train neural net
# ============================================================
tf.random.set_seed(42)

model = Sequential([
    InputLayer(shape=(X_train_s.shape[1],)),
    Dense(256, activation="relu"),
    BatchNormalization(),
    Dropout(0.2),

    Dense(128, activation="relu"),
    BatchNormalization(),
    Dropout(0.2),

    Dense(64, activation="relu"),
    Dense(1)
])

model.compile(
    optimizer=Adam(1e-3),
    loss="mape",
    metrics=["mape"]
)

callbacks = [
    EarlyStopping(monitor="val_loss", patience=10, restore_best_weights=True),
    ReduceLROnPlateau(monitor="val_loss", patience=5, factor=0.5, min_lr=1e-6),
]

history = model.fit(
    X_train_s, y_train,
    validation_data=(X_val_s, y_val),
    epochs=100,
    batch_size=256,
    callbacks=callbacks,
    verbose=1
)

model.save("3_Model/class file/python_model.keras")
# Out:
# Epoch 1/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 96.4105 - mape: 96.4105 - val_loss: 97.4990 - val_mape: 97.4990 - learning_rate: 0.0010
# Epoch 2/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 87.7636 - mape: 87.7636 - val_loss: 88.6566 - val_mape: 88.6566 - learning_rate: 0.0010
# Epoch 3/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 72.9948 - mape: 72.9948 - val_loss: 72.9595 - val_mape: 72.9595 - learning_rate: 0.0010
# Epoch 4/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 56.8352 - mape: 56.8352 - val_loss: 59.1796 - val_mape: 59.1796 - learning_rate: 0.0010
# Epoch 5/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 49.3139 - mape: 49.3139 - val_loss: 55.3504 - val_mape: 55.3504 - learning_rate: 0.0010
# Epoch 6/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 47.9489 - mape: 47.9489 - val_loss: 54.7113 - val_mape: 54.7113 - learning_rate: 0.0010
# Epoch 7/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 47.3815 - mape: 47.3815 - val_loss: 52.7594 - val_mape: 52.7594 - learning_rate: 0.0010
# Epoch 8/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 46.8661 - mape: 46.8661 - val_loss: 51.2459 - val_mape: 51.2459 - learning_rate: 0.0010
# Epoch 9/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 46.3883 - mape: 46.3883 - val_loss: 49.7082 - val_mape: 49.7082 - learning_rate: 0.0010
# Epoch 10/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 45.6773 - mape: 45.6773 - val_loss: 49.0379 - val_mape: 49.0379 - learning_rate: 0.0010
# Epoch 11/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 44.7963 - mape: 44.7963 - val_loss: 47.0479 - val_mape: 47.0479 - learning_rate: 0.0010
# Epoch 12/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 43.9315 - mape: 43.9315 - val_loss: 46.0516 - val_mape: 46.0516 - learning_rate: 0.0010
# Epoch 13/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 43.1328 - mape: 43.1328 - val_loss: 44.0475 - val_mape: 44.0475 - learning_rate: 0.0010
# Epoch 14/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 42.0802 - mape: 42.0802 - val_loss: 42.5205 - val_mape: 42.5205 - learning_rate: 0.0010
# Epoch 15/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 40.6374 - mape: 40.6374 - val_loss: 40.6324 - val_mape: 40.6324 - learning_rate: 0.0010
# Epoch 16/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 39.3832 - mape: 39.3832 - val_loss: 38.9790 - val_mape: 38.9790 - learning_rate: 0.0010
# Epoch 17/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 37.8257 - mape: 37.8257 - val_loss: 36.4927 - val_mape: 36.4927 - learning_rate: 0.0010
# Epoch 18/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 36.1539 - mape: 36.1539 - val_loss: 35.1003 - val_mape: 35.1003 - learning_rate: 0.0010
# Epoch 19/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 34.3479 - mape: 34.3479 - val_loss: 33.2165 - val_mape: 33.2165 - learning_rate: 0.0010
# Epoch 20/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 32.2231 - mape: 32.2231 - val_loss: 30.1615 - val_mape: 30.1615 - learning_rate: 0.0010
# Epoch 21/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 30.5797 - mape: 30.5797 - val_loss: 28.2020 - val_mape: 28.2020 - learning_rate: 0.0010
# Epoch 22/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 29.5526 - mape: 29.5526 - val_loss: 26.0851 - val_mape: 26.0851 - learning_rate: 0.0010
# Epoch 23/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 28.8060 - mape: 28.8060 - val_loss: 24.2809 - val_mape: 24.2809 - learning_rate: 0.0010
# Epoch 24/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 28.4989 - mape: 28.4989 - val_loss: 24.0078 - val_mape: 24.0078 - learning_rate: 0.0010
# Epoch 25/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 27.6024 - mape: 27.6024 - val_loss: 22.9903 - val_mape: 22.9903 - learning_rate: 0.0010
# Epoch 26/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 27.2197 - mape: 27.2197 - val_loss: 22.7800 - val_mape: 22.7800 - learning_rate: 0.0010
# Epoch 27/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 26.8083 - mape: 26.8083 - val_loss: 21.9711 - val_mape: 21.9711 - learning_rate: 0.0010
# Epoch 28/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 26.0824 - mape: 26.0824 - val_loss: 21.8222 - val_mape: 21.8222 - learning_rate: 0.0010
# Epoch 29/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 26.2054 - mape: 26.2054 - val_loss: 21.7364 - val_mape: 21.7364 - learning_rate: 0.0010
# Epoch 30/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 25.8728 - mape: 25.8728 - val_loss: 21.5268 - val_mape: 21.5268 - learning_rate: 0.0010
# Epoch 31/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 25.4752 - mape: 25.4752 - val_loss: 21.4008 - val_mape: 21.4008 - learning_rate: 0.0010
# Epoch 32/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 25.1115 - mape: 25.1115 - val_loss: 21.5274 - val_mape: 21.5274 - learning_rate: 0.0010
# Epoch 33/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 24.9359 - mape: 24.9359 - val_loss: 21.1241 - val_mape: 21.1241 - learning_rate: 0.0010
# Epoch 34/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 24.6048 - mape: 24.6048 - val_loss: 20.9452 - val_mape: 20.9452 - learning_rate: 0.0010
# Epoch 35/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 24.4771 - mape: 24.4771 - val_loss: 20.8566 - val_mape: 20.8566 - learning_rate: 0.0010
# Epoch 36/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 24.0105 - mape: 24.0105 - val_loss: 20.7877 - val_mape: 20.7877 - learning_rate: 0.0010
# Epoch 37/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 24.0307 - mape: 24.0307 - val_loss: 21.2912 - val_mape: 21.2912 - learning_rate: 0.0010
# Epoch 38/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 23.9894 - mape: 23.9894 - val_loss: 20.8486 - val_mape: 20.8486 - learning_rate: 0.0010
# Epoch 39/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 23.7919 - mape: 23.7919 - val_loss: 20.4529 - val_mape: 20.4529 - learning_rate: 0.0010
# Epoch 40/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 23.5979 - mape: 23.5979 - val_loss: 20.7966 - val_mape: 20.7966 - learning_rate: 0.0010
# Epoch 41/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 23.3266 - mape: 23.3266 - val_loss: 20.2018 - val_mape: 20.2018 - learning_rate: 0.0010
# Epoch 42/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 23.3795 - mape: 23.3795 - val_loss: 20.4052 - val_mape: 20.4052 - learning_rate: 0.0010
# Epoch 43/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 23.0794 - mape: 23.0794 - val_loss: 20.5126 - val_mape: 20.5126 - learning_rate: 0.0010
# Epoch 44/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 22.7437 - mape: 22.7437 - val_loss: 20.0693 - val_mape: 20.0693 - learning_rate: 0.0010
# Epoch 45/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 22.9963 - mape: 22.9963 - val_loss: 19.9841 - val_mape: 19.9841 - learning_rate: 0.0010
# Epoch 46/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 22.5651 - mape: 22.5651 - val_loss: 19.7136 - val_mape: 19.7136 - learning_rate: 0.0010
# Epoch 47/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 22.4973 - mape: 22.4973 - val_loss: 19.7166 - val_mape: 19.7166 - learning_rate: 0.0010
# Epoch 48/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 22.2371 - mape: 22.2371 - val_loss: 19.8319 - val_mape: 19.8319 - learning_rate: 0.0010
# Epoch 49/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 21.9969 - mape: 21.9969 - val_loss: 19.5972 - val_mape: 19.5972 - learning_rate: 0.0010
# Epoch 50/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 21.9685 - mape: 21.9685 - val_loss: 19.5975 - val_mape: 19.5975 - learning_rate: 0.0010
# Epoch 51/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 21.8521 - mape: 21.8521 - val_loss: 19.7120 - val_mape: 19.7120 - learning_rate: 0.0010
# Epoch 52/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 21.7821 - mape: 21.7821 - val_loss: 19.4118 - val_mape: 19.4118 - learning_rate: 0.0010
# Epoch 53/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 21.5281 - mape: 21.5281 - val_loss: 19.0093 - val_mape: 19.0093 - learning_rate: 0.0010
# Epoch 54/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 21.3076 - mape: 21.3076 - val_loss: 19.1695 - val_mape: 19.1695 - learning_rate: 0.0010
# Epoch 55/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 21.3007 - mape: 21.3007 - val_loss: 19.3741 - val_mape: 19.3741 - learning_rate: 0.0010
# Epoch 56/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 21.1890 - mape: 21.1890 - val_loss: 19.1866 - val_mape: 19.1866 - learning_rate: 0.0010
# Epoch 57/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 20.9766 - mape: 20.9766 - val_loss: 19.3456 - val_mape: 19.3456 - learning_rate: 0.0010
# Epoch 58/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 20.8890 - mape: 20.8890 - val_loss: 19.0675 - val_mape: 19.0675 - learning_rate: 0.0010
# Epoch 59/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 20.6683 - mape: 20.6683 - val_loss: 18.7517 - val_mape: 18.7517 - learning_rate: 5.0000e-04
# Epoch 60/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 20.4583 - mape: 20.4583 - val_loss: 18.9140 - val_mape: 18.9140 - learning_rate: 5.0000e-04
# Epoch 61/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 20.5708 - mape: 20.5708 - val_loss: 18.7672 - val_mape: 18.7672 - learning_rate: 5.0000e-04
# Epoch 62/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 20.1557 - mape: 20.1557 - val_loss: 18.4370 - val_mape: 18.4370 - learning_rate: 5.0000e-04
# Epoch 63/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 20.0656 - mape: 20.0656 - val_loss: 18.5304 - val_mape: 18.5304 - learning_rate: 5.0000e-04
# Epoch 64/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 20.3816 - mape: 20.3816 - val_loss: 18.4590 - val_mape: 18.4590 - learning_rate: 5.0000e-04
# Epoch 65/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 19.9979 - mape: 19.9979 - val_loss: 18.4835 - val_mape: 18.4835 - learning_rate: 5.0000e-04
# Epoch 66/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 19.9385 - mape: 19.9385 - val_loss: 18.3268 - val_mape: 18.3268 - learning_rate: 5.0000e-04
# Epoch 67/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 19.8176 - mape: 19.8176 - val_loss: 18.4887 - val_mape: 18.4887 - learning_rate: 5.0000e-04
# Epoch 68/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 20.0190 - mape: 20.0190 - val_loss: 18.5421 - val_mape: 18.5421 - learning_rate: 5.0000e-04
# Epoch 69/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 19.7148 - mape: 19.7148 - val_loss: 18.5421 - val_mape: 18.5421 - learning_rate: 5.0000e-04
# Epoch 70/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 19.4346 - mape: 19.4346 - val_loss: 18.3849 - val_mape: 18.3849 - learning_rate: 5.0000e-04
# Epoch 71/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 19.4387 - mape: 19.4387 - val_loss: 18.4490 - val_mape: 18.4490 - learning_rate: 5.0000e-04
# Epoch 72/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 19.5349 - mape: 19.5349 - val_loss: 18.2903 - val_mape: 18.2903 - learning_rate: 2.5000e-04
# Epoch 73/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 19.5055 - mape: 19.5055 - val_loss: 18.3364 - val_mape: 18.3364 - learning_rate: 2.5000e-04
# Epoch 74/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 19.3657 - mape: 19.3657 - val_loss: 18.1396 - val_mape: 18.1396 - learning_rate: 2.5000e-04
# Epoch 75/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 19.3522 - mape: 19.3522 - val_loss: 18.1454 - val_mape: 18.1454 - learning_rate: 2.5000e-04
# Epoch 76/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 19.2921 - mape: 19.2921 - val_loss: 18.1889 - val_mape: 18.1889 - learning_rate: 2.5000e-04
# Epoch 77/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 19.2124 - mape: 19.2124 - val_loss: 18.2929 - val_mape: 18.2929 - learning_rate: 2.5000e-04
# Epoch 78/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 19.2660 - mape: 19.2660 - val_loss: 18.1945 - val_mape: 18.1945 - learning_rate: 2.5000e-04
# Epoch 79/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 19.0981 - mape: 19.0981 - val_loss: 18.3476 - val_mape: 18.3476 - learning_rate: 2.5000e-04
# Epoch 80/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 18.9080 - mape: 18.9080 - val_loss: 18.3821 - val_mape: 18.3821 - learning_rate: 1.2500e-04
# Epoch 81/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 19.5208 - mape: 19.5208 - val_loss: 18.3055 - val_mape: 18.3055 - learning_rate: 1.2500e-04
# Epoch 82/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 19.1395 - mape: 19.1395 - val_loss: 18.3009 - val_mape: 18.3009 - learning_rate: 1.2500e-04
# Epoch 83/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 19.2352 - mape: 19.2352 - val_loss: 18.2228 - val_mape: 18.2228 - learning_rate: 1.2500e-04
# Epoch 84/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 18.9708 - mape: 18.9708 - val_loss: 18.1539 - val_mape: 18.1539 - learning_rate: 1.2500e-04

# %%
#load model
model = tf.keras.models.load_model(r"/workspaces/bakery_prediction/3_Model/01_ls_neuronal_net_model/3_Model/class file/python_model.keras")
# Out:
# 2026-01-06 16:41:31.195102: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)

# %%
#plot training history
import matplotlib.pyplot as plt 
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Val Loss')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.subplot(1, 2, 2)
plt.plot(history.history['val_mape'], label='Val MAPE')
plt.title('Model MAPE')
plt.xlabel('Epoch')
plt.ylabel('MAPE')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 5
#       3 plt.figure(figsize=(12, 5))
#       4 plt.subplot(1, 2, 1)
# ----> 5 plt.plot(history.history['loss'], label='Train Loss')
#       6 plt.plot(history.history['val_loss'], label='Val Loss')
#       7 plt.title('Model Loss')
#
# NameError: name 'history' is not defined

# %%
def mape_safe(y_true, y_pred, eps=1e-6):
    y_true = np.asarray(y_true)
    y_pred = np.asarray(y_pred)
    denom = np.maximum(np.abs(y_true), eps)
    return np.mean(np.abs((y_true - y_pred) / denom)) * 100

# %%
# ============================================================
# 5) Evaluate overall + per Warengruppe (VAL + TEST)
# ============================================================
def mape(y_true, y_pred):
    y_true = np.asarray(y_true).reshape(-1)
    y_pred = np.asarray(y_pred).reshape(-1)
    mask = y_true != 0
    return np.mean(np.abs((y_true[mask] - y_pred[mask]) / y_true[mask])) * 100

# ---- VAL: usar dados escalados e ignorar NaNs no alvo
mask_val = ~y_val.isna()
y_val_clean = y_val[mask_val].to_numpy()
val_pred = model.predict(X_val_s[mask_val.to_numpy()], verbose=0).reshape(-1)

print("VAL  MAE :", np.mean(np.abs(y_val_clean - val_pred)))
print("VAL  MAPE:", mape_safe(y_val_clean, val_pred))
print("VAL  R²  :", 1 - np.sum((y_val_clean - val_pred) ** 2) / np.sum((y_val_clean - np.mean(y_val_clean)) ** 2))
# Out:
# VAL  MAE : 31.92873695925383
# VAL  MAPE: 18.139562929968033
# VAL  R²  : 0.8305990033448667

# %%
# ============================================================
# 5) Evaluate overall + per Warengruppe (VAL + TEST)
# ============================================================

def get_warengruppe_series(df):
    if "Warengruppe" in df.columns:
        return df["Warengruppe"].astype(int)
    wg_cols = [c for c in df.columns if c.startswith("Warengruppe_")]
    prefix = "Warengruppe_"
    if not wg_cols:
        wg_cols = [c for c in df.columns if c.startswith("Group_")]
        prefix = "Group_"
    if not wg_cols:
        raise ValueError("Warengruppe not found neither as a column nor as one-hot (Warengruppe_*/Group_*).")
    return df[wg_cols].idxmax(axis=1).str.replace(prefix, "", regex=False).astype(int)

# ---- predictions with NaN-safe masks
mask_val = ~y_val.isna()
y_val_clean = y_val[mask_val].to_numpy()
val_pred = model.predict(X_val_s[mask_val.to_numpy()], verbose=0).reshape(-1)

mask_test = ~y_test.isna()
test_pred = None
if mask_test.any():
    y_test_clean = y_test[mask_test].to_numpy()
    test_pred = model.predict(X_test_s[mask_test.to_numpy()], verbose=0).reshape(-1)

# ---- overall metrics
print("VAL  MAE :", np.mean(np.abs(y_val_clean - val_pred)))
print("VAL  MAPE:", mape_safe(y_val_clean, val_pred))

if mask_test.any():
    print("TEST MAE :", np.mean(np.abs(y_test_clean - test_pred)))
    print("TEST MAPE:", mape_safe(y_test_clean, test_pred))
else:
    print("TEST metrics: skipped (all NaNs in y_test)")

# ---- per Warengruppe on VAL (using only valid rows)
df_val_eval = val_df.loc[mask_val].copy()
df_val_eval["Warengruppe"] = get_warengruppe_series(df_val_eval)
df_val_eval["y_true"] = y_val_clean
df_val_eval["y_pred"] = val_pred

mape_by_group_val = (
    df_val_eval.groupby("Warengruppe")
    .apply(lambda g: mape_safe(g["y_true"], g["y_pred"]))
    .reset_index(name="MAPE")
    .sort_values("Warengruppe")
)

print("\nMAPE by Warengruppe (VAL):")
print(mape_by_group_val.to_string(index=False))
print("\nMacro-MAPE (VAL):", mape_by_group_val["MAPE"].mean())
print("Micro-MAPE (VAL):", mape_safe(df_val_eval["y_true"], df_val_eval["y_pred"]))
# Out:
# VAL  MAE : 31.92873695925383
# VAL  MAPE: 18.139562929968033
# TEST metrics: skipped (all NaNs in y_test)
#
# MAPE by Warengruppe (VAL):
#  Warengruppe      MAPE
#            1 19.058673
#            2 12.424456
#            3 17.984806
#            4 22.388828
#            5 15.028076
#            6 42.447279
#
# Macro-MAPE (VAL): 21.555353116423134
# Micro-MAPE (VAL): 18.139562929968033
# /tmp/ipykernel_45952/3291281828.py:46: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   .apply(lambda g: mape_safe(g["y_true"], g["y_pred"]))

# %%
# X_test_s já escalado com scaler do train
test_pred = model.predict(X_test_s, verbose=0).reshape(-1)
#apenas id e predicao   
test_out = test_df[["id"]].copy()
test_out["Umsatz_pred"] = test_pred
test_out.to_csv("3_Model/nn_submission_2.csv", index=False)
print("Saved: 3_Model/nn_submission_2.csv")
# Out:
# Saved: 3_Model/nn_submission_2.csv
