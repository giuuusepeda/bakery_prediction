# %% [markdown]
# baseline model - linear reg

# %%
import pandas as pd
import sklearn
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt 
from sklearn.metrics import mean_absolute_error, r2_score
import statsmodels.api as sm

# %%
#need the splited dataset
df_baseline = pd.read_csv('/workspaces/bakery_prediction/0_DataPreparation/Processed/04_featured_data_with_weather_variables.csv', encoding= 'utf-8')

# %%
#filter only Warengruppe 1 
df_baseline = df_baseline[df_baseline['Warengruppe'] == 1]

# %%
#baseline datum to datetime
df_baseline['Datum'] = pd.to_datetime(df_baseline['Datum'], format='%Y-%m-%d')

# %%
#data types
df_baseline.dtypes

#list columns
df_baseline.columns
columns = ['Warengruppe', 'Umsatz', 'KielerWoche', 'Bewoelkung',
       'Temperatur', 'Windgeschwindigkeit', 'Woche', 'Monat',
       'Wochentag', 'Feiertag', 'Ferien']

# %%
sns.pairplot(df_baseline[columns])

# %%
#heatmap
plt.figure(figsize=(12,10))
correlation_matrix = df_baseline[columns].corr()
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.show()

# %%
X = sm.add_constant(df_[['Temperatur']])
Y = df_baseline['Umsatz']
X
# Out:
#        const  Temperatur
# 0        1.0     17.8375
# 5        1.0     17.3125
# 10       1.0     21.0750
# 15       1.0     18.8500
# 20       1.0     19.9750
# ...      ...         ...
# 11393    1.0     23.5375
# 11398    1.0     23.3500
# 11403    1.0     25.2500
# 11408    1.0     20.7375
# 11413    1.0     20.4500
#
# [2221 rows x 2 columns]

# %%
model = sm.OLS(Y, X)
results = model.fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 Umsatz   R-squared:                         nan
# Model:                            OLS   Adj. R-squared:                    nan
# Method:                 Least Squares   F-statistic:                       nan
# Date:                Wed, 26 Nov 2025   Prob (F-statistic):                nan
# Time:                        15:46:56   Log-Likelihood:                    nan
# No. Observations:                2221   AIC:                               nan
# Df Residuals:                    2219   BIC:                               nan
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const             nan        nan        nan        nan         nan         nan
# ...
